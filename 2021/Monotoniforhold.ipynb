# %% [markdown]
# <a href="https://colab.research.google.com/github/mrhenriksen/colab/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt update
# !sudo apt install libcairo2-dev ffmpeg texlive texlive-latex-extra texlive-fonts-extra texlive-latex-recommended texlive-science tipa libpango1.0-dev
# !pip install manim
# !pip install IPython --upgrade
# Out:
# Get:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:5 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:6 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# ...

# %%
from manim import *
# Out:
# Manim Community v0.13.1

# %%
# %%manim -qm -v WARNING MonotoniforholdIntro
#
# class MonotoniforholdIntro(Scene):
#   def construct(self):

# %%
# %%manim -qm -v WARNING MonotoniforholdEksempler
#
# class MonotoniforholdDefinition(Scene):
#   def construct(self):
#     text = Tex("test")
#
# class MonotoniforholdEksempler(Scene):
#   def construct(self):
#     np = NumberPlane(
#         x_range=[-7, 7],
#         y_range=[-2, 6],
#         x_length=14.22,
#         y_length=8,
#         axis_config={"include_numbers": False},
#         background_line_style={
#           "stroke_opacity": 0.6
#         }
#     )
#
#     self.play(Create(np))
#     self.wait()
#
#     graf1 = np.plot(lambda x: 2*x, color=TEAL, stroke_width=6)
#     graf2 = np.plot(lambda x: 2**-x, color=GOLD, stroke_width=6)
#     graf3 = np.plot(lambda x: 3, color=MAROON,stroke_width=6)
#
#     self.play(Create(graf1))
#     self.wait()
#     self.play(Create(graf2))
#     self.wait()
#     self.play(Create(graf3))
#     self.wait()
#
#     self.play(Uncreate(graf3))
#     self.play(Uncreate(graf2))
#     self.play(Uncreate(graf1))
#     self.wait()
#
#     def func(x):
#       return x**2
#     #parabel = np.plot(lambda x: x**2, color=MAROON)
#     parabel = np.plot(func, color=MAROON,stroke_width=6)
#     p1 = np.plot(lambda x: x**2, x_range=[-8,0],color=GOLD,stroke_width=6)
#     p2 = np.plot(lambda x: x**2, x_range=[0,8],color=GOLD,stroke_width=6)
#
#     inv1 = np.plot(lambda x: 0, x_range=[-8,0], color=YELLOW,stroke_width=6)
#     inv2 = np.plot(lambda x: 0, x_range=[0,8], color=YELLOW,stroke_width=6)
#
#     t = ValueTracker(-2)
#
#     start = [np.coords_to_point(t.get_value(),func(t.get_value()))]
#     punkt = Dot(point=start)
#     punkt.add_updater(lambda x: x.move_to(np.c2p(t.get_value(), func(t.get_value()))))
#
#
#     self.play(Create(parabel))
#     self.wait()
#     self.play(FadeIn(p1))
#     self.wait()
#     self.play(FadeIn(punkt))
#     self.wait()
#     self.play(t.animate.set_value(0),run_time=2)
#     self.wait()
#     self.play(FadeOut(p1))
#     self.wait()
#     self.play(FadeIn(p2))
#     self.wait()
#     self.play(t.animate.set_value(2),run_time=2)
#     self.play(FadeOut(p2))
#     self.wait()
#     self.play(FadeOut(punkt))
#     self.wait()
#
#     self.play(Create(inv1))
#     self.wait()
#
#     t.set_value(-3)
#
#     self.play(FadeIn(punkt))
#     self.play(t.animate.set_value(0),run_time=2)
#     self.wait()
#     self.play(Uncreate(inv1))
#     self.wait()
#     self.play(Create(inv2))
#     self.wait()
#     self.play(t.animate.set_value(3),run_time=2)
#     self.wait()
#     self.play(FadeOut(punkt))
#     self.wait()
#     self.play(Uncreate(inv2))
#     self.wait()
#
#     def funk(x):
#       return -0.0001265*x**6 + 0.0002013*x**5+0.005556*x**4+0.01574*x**3-0.1124*x**2-0.8034*x+2
#
#     graf4 = np.plot(funk,stroke_width=6)
#
#     self.play(Uncreate(parabel))
#     self.wait()
#     self.play(Create(graf4))
#
#     def1 = MathTex("x_1 < x_2 \\text{medfører} f(x_1) < f(x_2)")
#     def2 = MathTex("x_1 < x_2 \\text{medfører} f(x_1) > f(x_2)")
#
#     m = ValueTracker(-6)
#
#     start2 = [np.coords_to_point(m.get_value(),funk(m.get_value()))]
#     punkt2 = Dot(point=start)
#     punkt2.add_updater(lambda x: x.move_to(np.c2p(m.get_value(), funk(m.get_value()))))
#
#     hline = np.get_horizontal_line(np.c2p(m.get_value(), funk(m.get_value())), line_func=DashedLine,stroke_width=4)
#     vline = np.get_vertical_line(np.c2p(m.get_value(), funk(m.get_value())), line_func=DashedLine,stroke_width=4)
#     mov_hline = always_redraw(lambda: np.get_horizontal_line(np.c2p(m.get_value(), funk(m.get_value())),stroke_width=4))
#
#     self.play(FadeIn(punkt2))
#     self.wait()
#     #self.play(Create(hline),Create(vline))
#     self.add(mov_hline)
#     self.wait()
#     self.play(m.animate.set_value(-4),run_time=2)
#     self.wait()
#
#
#
#
#     self.wait(5)
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
