# %% [markdown]
# <a href="https://colab.research.google.com/github/mrhenriksen/colab/blob/main/2021/Manim_Toppunkt_for_parablen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt update
# !sudo apt install libcairo2-dev ffmpeg texlive texlive-latex-extra texlive-fonts-extra texlive-latex-recommended texlive-science tipa libpango1.0-dev
# !pip install manim
# !pip install IPython --upgrade
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [828 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# ...

# %%
from manim import *
# Out:
# Manim Community v0.12.0

# %%
# %%manim -qm -v WARNING parabola_vertex_intro
#
# class parabola_vertex_intro(Scene):
#   def construct(self):
#     title1 = Text("Andengradspolynomium", weight="SEMIBOLD", font="Open Sans")
#     title2 = Text("Toppunkt", gradient=(BLUE, GREEN), weight="HEAVY",font="Open Sans", font_size=96)
#
#     title2.to_corner(LEFT+DOWN)
#     title1.next_to(title2,UP).align_to(title2,LEFT)
#
#     self.play(Write(title1))
#     self.play(Write(title2))
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -qm -v WARNING Vertex1
#
#
# class Vertex1(MovingCameraScene):
#   def construct(self):
#     #self.play(self.camera.frame.animate.set(width=28.444))
#     numberplane = NumberPlane(
#         x_range=[-14, 14],
#         y_range=[-8, 8],
#         x_length=14.22,
#         y_length=8,
#         axis_config={"include_numbers": True}
#         #background_line_style={
#         #  "stroke_opacity": 0.6
#         #}
#     )
#
#
#     self.play(Create(numberplane))
#     self.wait()
#
#     graph1 = numberplane.plot(lambda x: x**2, color=RED)
#     graph2 = numberplane.plot(lambda x: 0.25*x**2, color=RED)
#     graph3 = numberplane.plot(lambda x: 3*x**2,color=RED)
#
#     graph4 = numberplane.plot(lambda x: x**2 - 3, color=GREEN)
#     graph5 = numberplane.plot(lambda x: x**2 + 2, color=GREEN)
#     graph6 = numberplane.plot(lambda x: x**2 + 7, color=GREEN)
#
#     graph7 = numberplane.plot(lambda x: (x+2)**2, color=BLUE)
#     graph8 = numberplane.plot(lambda x: (x-4)**2, color=BLUE)
#     graph9 = numberplane.plot(lambda x: (x-3)**2, color=BLUE)
#
#
#     self.play(Create(graph1))
#     self.wait()
#     self.play(Transform(graph1,graph2))
#     self.wait()
#     self.play(Transform(graph1,graph3))
#     self.wait()
#     self.play(Transform(graph1,graph4))
#     self.wait()
#     self.play(Transform(graph1,graph5))
#     self.wait()
#     self.play(Transform(graph1,graph6))
#     self.wait()
#     self.play(Transform(graph1,graph7))
#     self.wait()
#     self.play(Transform(graph1,graph8))
#     self.wait()
#     self.play(Transform(graph1,graph9))
#     self.wait()
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -qm -v WARNING NumberPlaneRangeExample
#
#
# class NumberPlaneRangeExample(MovingCameraScene):
#     def construct(self):
#         self.camera.frame.save_state()
#
#         number_plane_default = NumberPlane(axis_config={"include_numbers": True})
#         number_plane_custom = NumberPlane(
#             x_range=[-18, 18],
#             y_range=[-10, 10],
#             axis_config={"include_numbers": True}
#         )
#         number_plane_resized = NumberPlane(
#             x_range=[-14, 14],
#             y_range=[-8, 8],
#             x_length=14.22,
#             y_length=8,
#             axis_config={"include_numbers": True}
#         )
#         dot_coords = [10, 7, 0]
#         dot = Dot(point=dot_coords)
#
#         #self.add(number_plane_default, dot)
#         #self.play(self.camera.frame.animate.scale(2))
#         #self.wait()
#
#         #self.play(Restore(self.camera.frame))
#         #self.wait()
#
#         #self.remove(number_plane_default)
#         #self.add(number_plane_custom)
#         #self.play(self.camera.frame.animate.scale(2))
#         #self.wait()
#
#         #self.play(Restore(self.camera.frame))
#         #self.wait()
#
#         #self.play(AnimationGroup(
#         #    Transform(number_plane_custom, number_plane_resized)),
#         #    dot.animate.move_to(number_plane_resized.coords_to_point(*dot_coords))
#         #)
#         self.add(number_plane_resized)
#         self.wait()
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -qm -v WARNING Proof
#
# class Proof(Scene):
#   def construct(self):
#     eguation = MathTex("y=a\cdot (x-p)^2+q").to_edge(UP).shift(LEFT)
#     eq1 = MathTex("y","=3\cdot (x-4)^2+5").next_to(formel,DOWN).align_to(formel,LEFT)
#     eq2 = MathTex("=3\cdot (x^2+16-2\cdot 4\cdot x)+5").next_to(lign1,DOWN).align_to(lign1[1],LEFT)
#     eq3 = MathTex("=3\cdot x^2+{{3\cdot 16}}-3\cdot 8\cdot x+5").next_to(lign2,DOWN).align_to(lign1[1],LEFT)
#     eq4 = MathTex("=3\cdot x^2-24\cdot x+{{48+5}}").next_to(lign3,DOWN).align_to(lign1[1],LEFT)
#     eq5 = MathTex("={{3\cdot x^2}}-{{24}}\cdot x+{{53}}").next_to(lign4,DOWN).align_to(lign1[1],LEFT)
#
#     eq6 = MathTex("={{3\cdot x^2}}-{{24}}\cdot x+{{{{48}}+5}}").next_to(lign4,DOWN).align_to(lign1[1],LEFT)
#     #lign61 = MathTex("={{3x^2}}-{{24}}x+48+5").next_to(lign4,DOWN).align_to(lign1[1],LEFT)
#     eq7 = MathTex("={{3\cdot x^2}}-{{3\cdot 8}}\cdot x+{{48+5}}").next_to(lign4,DOWN).align_to(lign1[1],LEFT)
#     eq71 = MathTex("={{3\cdot x^2-3\cdot}} {{8}}\cdot x+{{48+5}}").next_to(lign4,DOWN).align_to(lign1[1],LEFT)
#     eq8 = MathTex("={{3\cdot x^2-3\cdot}} {{2\cdot 4\cdot}}\cdot x+{{48+5}}").next_to(lign4,DOWN).align_to(lign1[1],LEFT)
#     eq81 = MathTex("={{3\cdot x^2-3\cdot 2\cdot 4\cdot}}\cdot x+{{48}}+{{5}}").next_to(lign4,DOWN).align_to(lign1[1],LEFT)
#
#     eq9 = MathTex("={{3\cdot x^2-3\cdot 2\cdot 4\cdot}}\cdot x+{{3\cdot 16}}+{{5}}").next_to(lign4,DOWN).align_to(lign1[1],LEFT)
#     eq91 = MathTex("={{3\cdot x^2-3\cdot 2\cdot 4\cdot x+3\cdot}} {{16}}+{{5}}").next_to(lign4,DOWN).align_to(lign1[1],LEFT)
#     eq10 = MathTex("={{3\cdot x^2-3\cdot 2\cdot 4\cdot x+3\cdot}} {{4\cdot 4}}+{{5}}").next_to(lign4,DOWN).align_to(lign1[1],LEFT)
#     eq10a= MathTex("={{3\cdot x^2}}-{{3\cdot}} {{2\cdot}} {{4\cdot}} {{x+3\cdot}} {{4\cdot 4}}+{{5}}").next_to(lign4,DOWN).align_to(lign1[1],LEFT)
#     eq10b= MathTex("={{3\cdot x^2}}-{{2\cdot}} {{3\cdot}} {{4\cdot}} {{x+3\cdot}} {{4\cdot 4}}+{{5}}").next_to(lign4,DOWN).align_to(lign1[1],LEFT)
#     eq101= MathTex("=3\cdot {{x^2}}-{{2}}\cdot 3\cdot 4\cdot {{x}}+3\cdot 4\cdot 4+5").next_to(lign4,DOWN).align_to(lign1[1],LEFT)
#
#
#     eq11 = MathTex("=a\cdot {{x^2}}-{{2}}\cdot 3\cdot p\cdot {{x}}+a\cdot p\cdot p+q").next_to(lign4,DOWN).align_to(lign1[1],LEFT)
#     #lign111= MathTex("=ax^2-a\cdot 2\cdot p\cdot x+2\cdot p\cdot p+q").next_to(lign4,DOWN).align_to(lign1[1],LEFT)
#     #lign12 =
#
#     self.play(Write(equation))
#     self.wait(2)
#
#     self.play(Write(eq1))
#     self.wait()
#     self.play(Write(eq2))
#     self.wait()
#     self.play(Write(eq3))
#     self.wait()
#     self.play(Write(eq4))
#     self.wait()
#     self.play(Write(eq5))
#     self.wait()
#
#     self.play(Circumscribe(eq5.get_part_by_tex("53")))
#     self.wait(2)
#     self.play(Circumscribe(eq4.get_part_by_tex("48+5")))
#     self.wait()
#     self.play(TransformMatchingTex(eq5,eq6,run_time=2))
#     self.wait()
#
#     self.play(Circumscribe(eq6.get_part_by_tex("48")))
#     self.wait()
#     self.play(Circumscribe(eq3.get_part_by_tex("3\cdot 16")))
#     self.wait()
#     self.play(TransformMatchingTex(eq6,eq7,run_time=2))
#     self.add(eq71)
#     self.remove(eq7)
#     self.play(Replace(eq7,eq71))
#     self.wait()
#
#     self.play(Circumscribe(eq6.get_part_by_tex("24")))
#     self.wait()
#     self.play(Circumscribe(eq3.get_part_by_tex("3\cdot 16")))
#     self.wait()
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -qm -v WARNING Proof2
#
# class Proof2(Scene):
#   def construct(self):
#     equation = MathTex("y = {{a}}\cdot (x - {{p}})^2 + {{q}}").to_edge(UP).shift(LEFT)
#     eq1  = MathTex("y","= {{3}}\cdot (x - {{4}})^2 + {{7}}").next_to(equation,DOWN).align_to(equation,LEFT)
#     eq2a = MathTex("= {{3}}\cdot (x^2 + 4^2 - 2\cdot x\cdot 4) + 7").next_to(eq1,DOWN).align_to(eq1[1],LEFT)
#     eq2b = MathTex("= {{3}}\cdot (x^2 + {{4^2}} - {{2\cdot 4}}\cdot x) + 7").next_to(eq1,DOWN).align_to(eq1[1],LEFT)
#     eq3  = MathTex("= {{3}}\cdot (x^2 + 16 - 8\cdot x) + 7").next_to(eq2b,DOWN).align_to(eq1[1],LEFT)
#     eq4a = MathTex("= {{3}}\cdot x^2 + 3\cdot 16 - 3\cdot 8\cdot x + 7").next_to(eq3,DOWN).align_to(eq1[1],LEFT)
#     eq4b = MathTex("= {{3}}\cdot x^2 - {{3\cdot 8}}\cdot x + {{3\cdot 16 + 7}}").next_to(eq3,DOWN).align_to(eq1[1],LEFT)
#     eq5  = MathTex("= {{3}}\cdot x^2 - 24\cdot x + {{55}}").next_to(eq4b,DOWN).align_to(eq1[1],LEFT)
#
#     self.play(Create(equation))
#     self.wait()
#     self.play(Create(eq1))
#     self.wait()
#
#     text = Text("Kvadratsætning")
#     kvs1 = MathTex("(r + s)^2=","r^2","+s^2+","2\\cdot r\\cdot s")
#     kvs2 = MathTex("(r - s)^2=r^2+s^2-2\\cdot r\\cdot s")
#     kvs3 = MathTex("(r + s)\\cdot (r - s)=r^2-s^2")
#     kvs = VGroup(text,kvs1,kvs2,kvs3).arrange(DOWN)
#     text.align_to(kvs1,LEFT)
#     kvs3.align_to(kvs1,LEFT)
#     box = Rectangle().surround(kvs,buff=1)
#     factbox = VGroup(kvs,boks).shift(0.25*UP+0.25*RIGHT).scale(0.5).set_color(PURPLE).to_corner(UP+RIGHT)
#
#     self.play(Create(box))
#     self.play(Create(kvs))
#     self.wait(2)
#
#     self.play(Circumscribe(kvs2))
#     self.wait()
#
#     self.play(Create(eq2a))
#     self.wait()
#     self.play(FadeOut(factbox))
#     self.wait()
#     self.play(TransformMatchingShapes(eq2a,eq2b, path_arc=PI/2))
#     self.wait()
#     self.play(Create(eq3))
#     self.wait()
#     self.play(Create(eq4a))
#     self.wait()
#     self.play(TransformMatchingShapes(eq4a,eq4b, path_arc=PI/2))
#     self.wait()
#     self.play(Create(eq5))
#     self.wait()
#
#     self.play(Circumscribe(eq5.get_part_by_tex("55")))
#     self.wait(2)
#     self.play(Circumscribe(eq4b.get_part_by_tex("3\cdot 16 + 7")))
#     self.wait()
#
#     eq6a = MathTex("=3\cdot x^2 - 24\cdot x + 3\cdot {{16}} + 7").next_to(eq5,DOWN).align_to(eq1[1],LEFT)
#     eq6b = MathTex("=3\cdot x^2 - {{24}}\cdot x + 3\cdot 4^2 + 7").next_to(eq5,DOWN).align_to(eq1[1],LEFT)
#     eq6b1 = MathTex("{{=3\cdot x^2 - }}24{{\cdot x + 3\cdot 4^2 + 7}}").next_to(eq5,DOWN).align_to(eq1[1],LEFT)
#     eq6c = MathTex("=3\cdot x^2 - 3\cdot {{8}}\cdot x + 3\cdot 4^2 + 7").next_to(eq5,DOWN).align_to(eq1[1],LEFT)
#     eq6c1 = MathTex("{{=3\cdot x^2 - 3\cdot}} 8{{\cdot x + 3\cdot 4^2 + 7}}").next_to(eq5,DOWN).align_to(eq1[1],LEFT)
#     eq6d = MathTex("=3\cdot x^2 - 3\cdot 2\cdot 4\cdot x + 3\cdot 4^2 + 7").next_to(eq5,DOWN).align_to(eq1[1],LEFT)
#     eq6d1 = MathTex("{{=3\cdot x^2 - 3\cdot}} 2\cdot 4{{\cdot x + 3\cdot 4^2 + 7}}").next_to(eq5,DOWN).align_to(eq1[1],LEFT)
#     eq6e = MathTex("=3\cdot x^2 - 2\cdot 3\cdot 4\cdot x + 3\cdot 4^2 + 7").next_to(eq5,DOWN).align_to(eq1[1],LEFT)
#
#     self.play(Create(eq6a))
#     self.wait()
#
#     self.play(Circumscribe(eq6a.get_part_by_tex("16")))
#     self.wait(2)
#     self.play(Circumscribe(eq2b.get_part_by_tex("4^2")))
#     self.wait()
#
#     self.play(TransformMatchingTex(eq6a,eq6b,run_time=2))
#     self.wait()
#
#     self.play(Circumscribe(eq6b.get_part_by_tex("24")))
#     self.wait(2)
#     self.play(Circumscribe(eq4b.get_part_by_tex("3\cdot 8")))
#     self.wait()
#
#     self.add(eq6b1)
#     self.remove(eq6b)
#
#     self.play(TransformMatchingTex(eq6b1,lign6c,run_time=2))
#     self.wait()
#
#     self.play(Circumscribe(eq6c.get_part_by_tex("8")))
#     self.wait(2)
#     self.play(Circumscribe(eq2b.get_part_by_tex("2\cdot 4")))
#     self.wait()
#
#     self.add(eq6c1)
#     self.remove(eq6c)
#
#     self.play(TransformMatchingTex(eq6c1,eq6d1,run_time=2))
#     self.wait()
#     self.play(TransformMatchingShapes(eq6d1,eq6e,run_time=2, path_arc=PI/2))
#     self.wait()
#
#     self.play(equation.animate.set_color_by_tex("a",RED_C))
#     self.play(equation.animate.set_color_by_tex("p",BLUE_C))
#     self.play(equation.animate.set_color_by_tex("q",GREEN_C))
#     self.wait()
#
#     eq2bf = MathTex("= {{3}}\cdot (x^2 + {{4}}^2 - 2\cdot {{4}}\cdot x) + {{7}}").next_to(eq1,DOWN).align_to(eq1[1],LEFT)
#     eq3f  = MathTex("= {{3}}\cdot (x^2 + 16 - 8\cdot x) + {{7}}").next_to(eq2b,DOWN).align_to(eq1[1],LEFT)
#     eq4bf = MathTex("= {{3}}\cdot x^2 - {{3}}\cdot 8\cdot x + {{3}}\cdot 16 + {{7}}").next_to(eq3,DOWN).align_to(eq1[1],LEFT)
#     eq5f  = MathTex("= {{3}}\cdot x^2 - 24\cdot x + 55",).next_to(eq4b,DOWN).align_to(eq1[1],LEFT)
#     eq6ef = MathTex("={{3}}\cdot x^2 - 2\cdot {{3}}\cdot {{4}}\cdot x + {{3}}\cdot {{4}}^2 + {{7}}").next_to(eq5,DOWN).align_to(eq1[1],LEFT)
#
#     self.add(eq2bf,eq3f,eq4bf,eq5f,eq6ef)
#     self.remove(eq2b,eq3,eq4b,eq5,eq6e)
#
#     self.play(eq1.animate.set_color_by_tex("3",RED_C))
#     self.play(eq2bf.animate.set_color_by_tex("3",RED_C))
#     self.play(eq3f.animate.set_color_by_tex("3",RED_C))
#     self.play(eq4bf.animate.set_color_by_tex("3",RED_C))
#     self.play(eq5f.animate.set_color_by_tex("3",RED_C))
#     self.play(eq6ef.animate.set_color_by_tex("3",RED_C))
#     self.wait()
#     self.play(eq1.animate.set_color_by_tex("4",BLUE_C))
#     self.play(eq2bf.animate.set_color_by_tex("4",BLUE_C))
#     self.play(eq3f.animate.set_color_by_tex("4",BLUE_C))
#     self.play(eq4bf.animate.set_color_by_tex("4",BLUE_C))
#     self.play(eq6ef.animate.set_color_by_tex("4",BLUE_C))
#     self.wait()
#     self.play(eq1.animate.set_color_by_tex("7",GREEN_C))
#     self.play(eq2bf.animate.set_color_by_tex("7",GREEN_C))
#     self.play(eqe3f.animate.set_color_by_tex("7",GREEN_C))
#     self.play(eq4bf.animate.set_color_by_tex("7",GREEN_C))
#     self.play(eq6ef.animate.set_color_by_tex("7",GREEN_C))
#     self.wait()
#
#     #equation.set_color_by_tex("x", YELLOW)
#
#     eq7a = MathTex("={{a}}\cdot x^2 - 2\cdot {{a}}\cdot {{p}}\cdot x + {{a}}\cdot {{p}}^2 + {{q}}").next_to(eq5,DOWN).align_to(eq1[1],LEFT)
#     eq7b = MathTex("={{a}}\cdot x^2 + (- 2\cdot {{a}}\cdot {{p}})\cdot x + {{a}}\cdot {{p}}^2 + {{q}}").next_to(eq5,DOWN).align_to(eq1[1],LEFT)
#     eq7b1= MathTex("=a\cdot {{x^2}} + (- 2\cdot a\cdot p)\cdot {{x}} + a\cdot p^2 + q").next_to(eq5,DOWN).align_to(eq1[1],LEFT)
#     eq8  = MathTex("=a\cdot {{x^2}} + b\cdot {{x}} + c").next_to(eq7b1,DOWN).align_to(eq1[1],LEFT)
#
#     eq7a.set_color_by_tex("a",RED_C)
#     eq7a.set_color_by_tex("p",BLUE_C)
#     eq7a.set_color_by_tex("q",GREEN_C)
#     eq7b.set_color_by_tex("a",RED_C)
#     eq7b.set_color_by_tex("p",BLUE_C)
#     eq7b.set_color_by_tex("q",GREEN_C)
#
#     self.play(TransformMatchingTex(eq6ef,eq7a,run_time=2))
#     self.wait()
#     self.play(TransformMatchingTex(eq7a,eq7b,run_time=2))
#     self.wait()
#
#     self.add(eq7b1)
#     self.remove(eq7b)
#
#     self.play(TransformMatchingTex(eq7b1.copy(),eq8,run_time=2))
#     self.wait()
#
#     eq7c = MathTex("=a\cdot x^2 + (","- 2\cdot a\cdot p",")\cdot {{x}} + ","a\cdot p^2 + q").next_to(eq5,DOWN).align_to(eq1[1],LEFT)
#     eq8a = MathTex("=a\cdot x^2 + ","b","\cdot x + ","c").next_to(eq7b1,DOWN).align_to(eq1[1],LEFT)
#
#     self.add(eq7c,eq8a)
#     self.remove(eq7b1,eq8)
#
#     eq9 = MathTex("b","=","- 2\cdot a\cdot p").to_corner(UP+LEFT)
#     eq10= MathTex("c","=","a\cdot p^2 + q").to_corner(UP+LEFT).shift(3*RIGHT)
#     eq11 = MathTex("p ="," - {b\over 2\cdot a}").next_to(eq9,DOWN).align_to(eq9,LEFT)
#     eq12 = MathTex("q ","= c - a\cdot ","p","^2").next_to(eq10,DOWN).align_to(eq10,LEFT)
#
#     self.play(FadeOut(equation)),
#               FadeOut(eq1),
#               FadeOut(eq2bf),
#               FadeOut(eq3f),
#               FadeOut(eq4bf),
#               FadeOut(eq5f),
#               FadeOut(eq7c),
#               FadeOut(eq8a),
#               TransformMatchingShapes(eq7c[1].copy(),eq9[2],run_time=2),
#               TransformMatchingShapes(eq8a[1].copy(),eq9[0],run_time=2),
#               FadeIn(eq9[1]),
#               TransformMatchingShapes(eq7c[3].copy(),eq10[2]),
#               TransformMatchingShapes(eq8a[3].copy(),eq10[0]),
#               FadeIn(eq10[1]),
#              )
#     self.wait()
#
#     self.play(TransformMatchingShapes(eq9.copy(),eq11,run_time=2, path_arc=PI/2))
#     self.wait()
#
#     self.play(TransformMatchingShapes(eq10.copy(),eq12,run_time=2, path_arc=PI/2))
#     self.wait()
#
#     #lign12a = MathTex("=c - a\cdot","\big("," - {b\over 2\cdot a}","\big)","^2").next_to(lign12,DOWN).align_to(lign12[1],LEFT)
#     #lign12b = MathTex("=c - a\cdot {b^2\over(2\cdot a)^2}").next_to(lign12,DOWN).align_to(lign12[1],LEFT)
#     #lign12c = MathTex("=c - a\cdot {b^2\over 4\cdot a^2}").next_to(lign12,DOWN).align_to(lign12[1],LEFT)
#     #lign12d = MathTex("=c - {b^2\over 4\cdot a}").next_to(lign12,DOWN).align_to(lign12[1],LEFT)
#     #lign12e = MathTex("={4\cdot a\cdot c\over 4\cdot a} - {b^2\over 4\cdot a}").next_to(lign12,DOWN).align_to(lign12[1],LEFT)
#     #lign12f = MathTex("={4\cdot a\cdot c - b^2\over 4\cdot a}").next_to(lign12,DOWN).align_to(lign12[1],LEFT)
#     #lign12g = MathTex("={- b^2+4\cdot a\cdot c\over 4\cdot a}").next_to(lign12,DOWN).align_to(lign12[1],LEFT)
#     #lign12h = MathTex("={- (b^2-4\cdot a\cdot c)\over 4\cdot a}").next_to(lign12,DOWN).align_to(lign12[1],LEFT)
#     #lign12i = MathTex("=-{D\over 4\cdot a}").next_to(lign12,DOWN).align_to(lign12[1],LEFT)
#
#     #self.play(TransformMatchingShapes(lign12,lign12a))
#     #self.wait()
#     #self.play(TransformMatchingShapes(lign12a,lign12b))
#     #self.wait()
#     #self.play(TransformMatchingShapes(lign12b,lign12c))
#     #self.wait()
#     #self.play(TransformMatchingShapes(lign12c,lign12d))
#     #self.wait()
#     #self.play(TransformMatchingShapes(lign12d,lign12e))
#     #self.wait()
#     #self.play(TransformMatchingShapes(lign12e,lign12f))
#     #self.wait()
#     #self.play(TransformMatchingShapes(lign12f,lign12g))
#     #self.wait()
#     #self.play(TransformMatchingShapes(lign12g,lign12h))
#     #self.wait()
#     #self.play(TransformMatchingShapes(lign12h,lign12i))
#     #self.wait()
#
#     text11 = Text(r"Toppunktet kan derfor aflæses direkte").scale(0.7)
#     text112= Text(r"når andengradsligningen er på formen").scale(0.7)
#     eguation1 = MathTex(r"y=a(x-p)^2+q")
#     text12 = Text(r"til at være").scale(0.5)
#     equation2 = MathTex(r"T=(p,q)")
#     ft1 = VGroup(text11,text112,equation1,text12,equation2).arrange(DOWN).scale(0.7)
#     text12.align_to(text11,LEFT)
#     text112.align_to(text11,LEFT)
#     box1 = SurroundingRectangle(ft1, buff=0.25)
#     theorem1 = VGroup(ft1,box1).to_corner(UP+RIGHT)
#
#     text21 = Text(r"Mens toppunktet skal beregnes").scale(0.7)
#     text212 = Text(r"når den er på den klassiske form").scale(0.7)
#     equation3 = MathTex(r"y=ax^2+bx+c")
#     text22 = Text(r"ved hjælp af").scale(0.7)
#     equation4 = MathTex(r"T=(-\frac{b}{2a}, -\frac{D}{4a})")
#     ft2 = VGroup(text21,text212,equation3,text22,equation4).arrange(DOWN).scale(0.5)
#     text22.align_to(text21,LEFT)
#     text212.align_to(text21,LEFT)
#     box2 = SurroundingRectangle(ft2, buff=0.25)
#     theorem2 = VGroup(ft2,box2).next_to(theorem1,DOWN).align_to(theorem1,LEFT)
#
#     self.play(Create(theorem1))
#     self.wait()
#     self.play(Create(theorem2))
#
#     self.wait(5)
# Out:
# [11/23/21 14:03:07] ERROR    LaTeX compilation error: Missing $       ]8;id=21904;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=171316;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py#266\266]8;;\
#                              inserted.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-8b8578615098> in <module>
# ...
